# %%
from plotbot import *
# Out:
# initialized server_access
# initialized global_tracker
# initialized plot_config
# initialized data_cubby
# initialized plot_manager
# CDF classes added to data_cubby type map.
# initialized epad class
# initialized epad_hr class
# initialized proton class
# initialized proton_hr class
# initialized proton_fits class
# initialized alpha_fits class
# initialized psp_alpha class
# initialized psp_qtn class
# initialized psp_orbit class
# initialized psp_span_vdf class
# 🎛️ initialized ploptions
#
# Importing libraries, this may take a moment. Hold tight...
#
# ✅ Imported standard libraries and utilities.
# ✅ Deferred numpy, pandas, and scipy libraries (loaded when needed).
# ✅ Deferred matplotlib libraries (loaded when needed).
# ✅ Deferred heavy data libraries (cdflib, requests, bs4) - loaded when needed.
#
# 🤖 Plotbot Initialized
# 🔍 [YLIMIT INIT DEBUG] plotbot function loaded from: plotbot.plotbot_main, id: 5790920160
# ✨ Showdahodo initialized
# Positional Data Helper Initialized
# ...

# %%
# Cell 1: Create custom variable and plot it
trange = ['2021-01-17/12:00:00', '2021-01-17/18:00:00']

my_var = custom_variable('my_var', lambda: proton.density * 2)
my_var.color = 'purple'
my_var.y_label = 'Density × 2'

# print('hello')

plotbot(trange, my_var, 1)
# Out:
# 🔍 [YLIMIT DEBUG] ENTERED plotbot() - we are HERE
# 🔍 [YLIMIT DEBUG] old_var ID: 5810192208, result ID: 5778975824
# 🔍 [YLIMIT DEBUG] old_var.y_limit (property getter): None
# 🔍 [YLIMIT DEBUG] old_var.plot_config.y_limit: None
# 🔍 [YLIMIT DEBUG] old_var.__dict__.get('y_limit'): NOT IN __dict__
# 🔍 [YLIMIT DEBUG] old_var._plot_state.get('y_limit'): NOT IN _plot_state
# 🔍 [YLIMIT DEBUG] Copying color=purple via setattr
# 🔍 [YLIMIT DEBUG] Copying y_label=Density × 2 via setattr
# 🔍 [YLIMIT DEBUG] Copying legend_label=my_var via setattr
# 🔍 [YLIMIT DEBUG] Copying plot_type=time_series via setattr
# 🔍 [YLIMIT DEBUG] Copying y_scale=linear via setattr
# 🔍 [YLIMIT DEBUG] Copying line_style=- via setattr
# 🔍 [YLIMIT DEBUG] Copying marker_size=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying marker_style=. via setattr
# 🔍 [YLIMIT DEBUG] Copying line_width=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying alpha=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying colormap=viridis via setattr
# ...

# %%
# Cell 2: Change y_limit and plot again
my_var.y_limit = [0, 3000]

plotbot(trange, my_var, 1)
# Out:
# 🔍 [YLIMIT DEBUG] ENTERED plotbot() - we are HERE
# 🔍 [YLIMIT DEBUG] old_var ID: 5778975824, result ID: 5810759504
# 🔍 [YLIMIT DEBUG] old_var.y_limit (property getter): None
# 🔍 [YLIMIT DEBUG] old_var.plot_config.y_limit: None
# 🔍 [YLIMIT DEBUG] old_var.__dict__.get('y_limit'): NOT IN __dict__
# 🔍 [YLIMIT DEBUG] old_var._plot_state.get('y_limit'): NOT IN _plot_state
# 🔍 [YLIMIT DEBUG] Copying color=purple via setattr
# 🔍 [YLIMIT DEBUG] Copying y_label=Density × 2 via setattr
# 🔍 [YLIMIT DEBUG] Copying legend_label=my_var via setattr
# 🔍 [YLIMIT DEBUG] Copying plot_type=time_series via setattr
# 🔍 [YLIMIT DEBUG] Copying y_scale=linear via setattr
# 🔍 [YLIMIT DEBUG] Copying line_style=- via setattr
# 🔍 [YLIMIT DEBUG] Copying marker_size=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying marker_style=. via setattr
# 🔍 [YLIMIT DEBUG] Copying line_width=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying alpha=1.0 via setattr
# 🔍 [YLIMIT DEBUG] Copying colormap=viridis via setattr
# ...
